# %% [markdown]
# # 모듈 module
#
# - .py 파일을 의미
# - 코드 재사용성을 높이기 위해 모듈단위로 관련있는 것들을 묶어서 관리
# - 모듈하위의 변수, 함수, 클래스 등을 외부에서 임포트 후 사용이 가능
# - private 변수 선언시에는 외부에서 접근 불가

# %%
import math

print(dir(math)) # 특정 모듈의 사용가능한 변수들
print(dir()) # 현재모듈의 사용가능한 변수
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '__vsc_ipynb_file__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'math', 'open', 'quit']

# %%
# 현재 모듈 이름
print(__name__)

# import한 모듈 이름
print(math.__name__)
# Out:
# __main__
# math

# %% [markdown]
# # 사용자 모듈 가져오기

# %%
# import songpawork.my_math

# print(songpawork.my_math.x)
# print(songpawork.my_math.pi)
# print(songpawork.my_math.get_circle_area(10))

# %%
# 모듈 import를 추천
from songpawork import my_math as m

print(m.x)
print(m.pi)
print(m.get_circle_area(10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 # 모듈 import를 추천
#       2 from songpawork import my_math as m
#       3
# ----> 4 print(m.x)
#       5 print(m.pi)
#       6 print(m.get_circle_area(10))
#
# AttributeError: module 'songpawork.my_math' has no attribute 'x'

# %%
# 현재 모듈의 변수와 이름충돌이 우려
from songpawork.my_math import x, pi, get_circle_area
# from songpawork.my_math import * # 비추

print(x)
print(pi)
# print(__z) #에서는 오류발생
print(get_circle_area(10))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 현재 모듈의 변수와 이름충돌이 우려
# ----> 2 from songpawork.my_math import x, pi, get_circle_area
#       3 # from songpawork.my_math import * # 비추
#       4
#       5 print(x)
#
# ImportError: cannot import name 'x' from 'songpawork.my_math' (d:\정해원\Songpa-TIL\실습 코드\12_AI\01-python\08_module\songpawork\my_math.py)

# %%
from songpawork import my_math as m

print(m.__file__)
print(dir(m))
# Out:
# d:\정해원\Songpa-TIL\실습 코드\12_AI\01-python\08_module\songpawork\my_math.py
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']
